# %%
#r "nuget: OpenCvSharp4, 4.13.0.20260602"
#r "nuget: OpenCvSharp4.official.runtime.linux-x64, 4.13.0.20260602"
#!csharp

# %%
#!csharp
using OpenCvSharp;
Vec4d vector1 = new Vec4d(1.0, 2.0, 3.0, 4.0);
Vec4d vector2 = new Vec4d(5.0, 6.0, 7.0, 8.0);

# %%
Console.WriteLine($"Vector 1: {vector1}");
Console.WriteLine($"Vector 2: {vector2}");
Console.WriteLine($"Dot Product: {vector1.Dot(vector2)}");
